# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('heart disease.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
#  12  Age_bins        918 non-null    category
# dtypes: category(1), float64(1), int64(6), object(5)
# memory usage: 87.3+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# Age_bins          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease', 'Age_bins'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Visual format of DATA

# %%
sns.displot(df['Age'], kde = True, color = 'blue')

# %%
sns.displot(df['RestingBP'], kde = False, color = 'blue')

# %%
sns.displot(df['MaxHR'], kde = True, color = 'blue')

# %%
sns.displot(df['FastingBS'], kde = True, color = 'blue')

# %% [markdown]
# Categorical columns(Pie charts)

# %%
df.groupby('Sex').size().plot(kind = 'pie', autopct = '%.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie', autopct = '%.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind = 'pie', autopct = '%.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie', autopct = '%.1f', figsize = (6,6))
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie', autopct = '%.1f', figsize = (6,6))
# Out:
# <Axes: >

# %% [markdown]
# violin plot

# %%
sns.violinplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(y = df['Sex'], x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y = df['Cholesterol'], x = df['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
numerical_columns = df.select_dtypes(include='number')
correlation_matrix = numerical_columns.corr()

# Styling the correlation matrix
styled_corr_matrix = correlation_matrix.style.background_gradient(cmap='coolwarm')

# Display the styled correlation matrix
styled_corr_matrix
# Out:
# <style type="text/css">
# #T_cfd81_row0_col0, #T_cfd81_row1_col1, #T_cfd81_row2_col2, #T_cfd81_row3_col3, #T_cfd81_row4_col4, #T_cfd81_row5_col5, #T_cfd81_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cfd81_row0_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_cfd81_row0_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_cfd81_row0_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_cfd81_row0_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_cfd81_row0_col5, #T_cfd81_row1_col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_cfd81_row0_col6, #T_cfd81_row6_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_cfd81_row1_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_cfd81_row1_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_cfd81_row1_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_cfd81_row1_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_cfd81_row1_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_cfd81_row2_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_cfd81_row2_col1, #T_cfd81_row3_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_cfd81_row2_col3, #T_cfd81_row3_col2, #T_cfd81_row4_col0, #T_cfd81_row4_col1, #T_cfd81_row4_col5, #T_cfd81_row4_col6, #T_cfd81_row6_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_cfd81_row2_col4 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_cfd81_row2_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_cfd81_row2_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_cfd81_row3_col0, #T_cfd81_row6_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_cfd81_row3_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_cfd81_row3_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_cfd81_row3_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_cfd81_row4_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_cfd81_row4_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_cfd81_row5_col0 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_cfd81_row5_col1, #T_cfd81_row5_col2, #T_cfd81_row5_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_cfd81_row5_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_cfd81_row5_col6 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_cfd81_row6_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_cfd81_row6_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_cfd81_row6_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cfd81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfd81_level0_col0" class="col_heading level0 col0" >Age</th>
#       <th id="T_cfd81_level0_col1" class="col_heading level0 col1" >RestingBP</th>
#       <th id="T_cfd81_level0_col2" class="col_heading level0 col2" >Cholesterol</th>
#       <th id="T_cfd81_level0_col3" class="col_heading level0 col3" >FastingBS</th>
#       <th id="T_cfd81_level0_col4" class="col_heading level0 col4" >MaxHR</th>
#       <th id="T_cfd81_level0_col5" class="col_heading level0 col5" >Oldpeak</th>
#       <th id="T_cfd81_level0_col6" class="col_heading level0 col6" >HeartDisease</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfd81_level0_row0" class="row_heading level0 row0" >Age</th>
#       <td id="T_cfd81_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_cfd81_row0_col1" class="data row0 col1" >0.254399</td>
#       <td id="T_cfd81_row0_col2" class="data row0 col2" >-0.095282</td>
#       <td id="T_cfd81_row0_col3" class="data row0 col3" >0.198039</td>
#       <td id="T_cfd81_row0_col4" class="data row0 col4" >-0.382045</td>
#       <td id="T_cfd81_row0_col5" class="data row0 col5" >0.258612</td>
#       <td id="T_cfd81_row0_col6" class="data row0 col6" >0.282039</td>
#     </tr>
#     <tr>
#       <th id="T_cfd81_level0_row1" class="row_heading level0 row1" >RestingBP</th>
#       <td id="T_cfd81_row1_col0" class="data row1 col0" >0.254399</td>
#       <td id="T_cfd81_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_cfd81_row1_col2" class="data row1 col2" >0.100893</td>
#       <td id="T_cfd81_row1_col3" class="data row1 col3" >0.070193</td>
#       <td id="T_cfd81_row1_col4" class="data row1 col4" >-0.112135</td>
#       <td id="T_cfd81_row1_col5" class="data row1 col5" >0.164803</td>
#       <td id="T_cfd81_row1_col6" class="data row1 col6" >0.107589</td>
#     </tr>
#     <tr>
#       <th id="T_cfd81_level0_row2" class="row_heading level0 row2" >Cholesterol</th>
#       <td id="T_cfd81_row2_col0" class="data row2 col0" >-0.095282</td>
#       <td id="T_cfd81_row2_col1" class="data row2 col1" >0.100893</td>
#       <td id="T_cfd81_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_cfd81_row2_col3" class="data row2 col3" >-0.260974</td>
#       <td id="T_cfd81_row2_col4" class="data row2 col4" >0.235792</td>
#       <td id="T_cfd81_row2_col5" class="data row2 col5" >0.050148</td>
#       <td id="T_cfd81_row2_col6" class="data row2 col6" >-0.232741</td>
#     </tr>
#     <tr>
#       <th id="T_cfd81_level0_row3" class="row_heading level0 row3" >FastingBS</th>
#       <td id="T_cfd81_row3_col0" class="data row3 col0" >0.198039</td>
#       <td id="T_cfd81_row3_col1" class="data row3 col1" >0.070193</td>
#       <td id="T_cfd81_row3_col2" class="data row3 col2" >-0.260974</td>
#       <td id="T_cfd81_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_cfd81_row3_col4" class="data row3 col4" >-0.131438</td>
#       <td id="T_cfd81_row3_col5" class="data row3 col5" >0.052698</td>
#       <td id="T_cfd81_row3_col6" class="data row3 col6" >0.267291</td>
#     </tr>
#     <tr>
#       <th id="T_cfd81_level0_row4" class="row_heading level0 row4" >MaxHR</th>
#       <td id="T_cfd81_row4_col0" class="data row4 col0" >-0.382045</td>
#       <td id="T_cfd81_row4_col1" class="data row4 col1" >-0.112135</td>
#       <td id="T_cfd81_row4_col2" class="data row4 col2" >0.235792</td>
#       <td id="T_cfd81_row4_col3" class="data row4 col3" >-0.131438</td>
#       <td id="T_cfd81_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_cfd81_row4_col5" class="data row4 col5" >-0.160691</td>
#       <td id="T_cfd81_row4_col6" class="data row4 col6" >-0.400421</td>
#     </tr>
#     <tr>
#       <th id="T_cfd81_level0_row5" class="row_heading level0 row5" >Oldpeak</th>
#       <td id="T_cfd81_row5_col0" class="data row5 col0" >0.258612</td>
#       <td id="T_cfd81_row5_col1" class="data row5 col1" >0.164803</td>
#       <td id="T_cfd81_row5_col2" class="data row5 col2" >0.050148</td>
#       <td id="T_cfd81_row5_col3" class="data row5 col3" >0.052698</td>
#       <td id="T_cfd81_row5_col4" class="data row5 col4" >-0.160691</td>
#       <td id="T_cfd81_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_cfd81_row5_col6" class="data row5 col6" >0.403951</td>
#     </tr>
#     <tr>
#       <th id="T_cfd81_level0_row6" class="row_heading level0 row6" >HeartDisease</th>
#       <td id="T_cfd81_row6_col0" class="data row6 col0" >0.282039</td>
#       <td id="T_cfd81_row6_col1" class="data row6 col1" >0.107589</td>
#       <td id="T_cfd81_row6_col2" class="data row6 col2" >-0.232741</td>
#       <td id="T_cfd81_row6_col3" class="data row6 col3" >0.267291</td>
#       <td id="T_cfd81_row6_col4" class="data row6 col4" >-0.400421</td>
#       <td id="T_cfd81_row6_col5" class="data row6 col5" >0.403951</td>
#       <td id="T_cfd81_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.jointplot(x = 'Age' , y = 'MaxHR', data = df)

# %%
sns.jointplot(x = 'Age' , y = 'MaxHR', data = df, kind = 'reg')

# %%
sns.jointplot(x = 'Cholesterol' , y = 'MaxHR', data = df, kind = 'reg')

# %%
sns.jointplot(x = 'Cholesterol' , y = 'MaxHR', data = df, kind = 'reg')
